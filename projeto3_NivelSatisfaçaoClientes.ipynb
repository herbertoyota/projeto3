# %%
import sklearn as sl
import warnings
warnings.filterwarnings("ignore")
sl.__version__
# Out:
# '0.22.1'

# %%
from pandas import read_csv
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
print(dados.shape)
# Out:
# (76020, 371)

# %%
dados.describe()
# Out:
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   76020.000000   76020.000000  76020.000000        76020.000000
# mean    75964.050723   -1523.199277     33.212865           86.208265
# std     43781.947379   39033.462364     12.956486         1614.757313
# min         1.000000 -999999.000000      5.000000            0.000000
# 25%     38104.750000       2.000000     23.000000            0.000000
# 50%     76043.000000       2.000000     28.000000            0.000000
# 75%    113748.750000       2.000000     40.000000            0.000000
# max    151838.000000     238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               12888.030000             21024.810000
#
#        imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# count             76020.000000             76020.000000
# mean                  3.559130                 6.472698
# std                  93.155749               153.737066
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                8237.820000             11073.570000
#
#        imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  ...  \
# count             76020.000000             76020.000000  ...
# mean                  0.412946                 0.567352  ...
# std                  30.604864                36.513513  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   0.000000                 0.000000  ...
# 75%                   0.000000                 0.000000  ...
# max                6600.000000              6600.000000  ...
#
#        saldo_medio_var33_hace2  saldo_medio_var33_hace3  \
# count             76020.000000             76020.000000
# mean                  7.935824                 1.365146
# std                 455.887218               113.959637
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               50003.880000             20385.720000
#
#        saldo_medio_var33_ult1  saldo_medio_var33_ult3  \
# count            76020.000000            76020.000000
# mean                12.215580                8.784074
# std                783.207399              538.439211
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max             138831.630000            91778.730000
#
#        saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# count             76020.000000             76020.000000
# mean                 31.505324                 1.858575
# std                2013.125393               147.786584
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max              438329.220000             24650.010000
#
#        saldo_medio_var44_ult1  saldo_medio_var44_ult3         var38  \
# count            76020.000000            76020.000000  7.602000e+04
# mean                76.026165               56.614351  1.172358e+05
# std               4040.337842             2852.579397  1.826646e+05
# min                  0.000000                0.000000  5.163750e+03
# 25%                  0.000000                0.000000  6.787061e+04
# 50%                  0.000000                0.000000  1.064092e+05
# 75%                  0.000000                0.000000  1.187563e+05
# max             681462.900000           397884.300000  2.203474e+07
#
#              TARGET
# count  76020.000000
# mean       0.039569
# std        0.194945
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 371 columns]

# %%
dados.corr(method= 'pearson')
# Out:
#                                ID      var3     var15  imp_ent_var16_ult1  \
# ID                       1.000000 -0.001025 -0.002135           -0.003111
# var3                    -0.001025  1.000000 -0.004452            0.001868
# var15                   -0.002135 -0.004452  1.000000            0.043722
# imp_ent_var16_ult1      -0.003111  0.001868  0.043722            1.000000
# imp_op_var39_comer_ult1 -0.001436  0.005989  0.094762            0.041221
# ...                           ...       ...       ...                 ...
# saldo_medio_var44_hace3 -0.003674  0.000508  0.018884           -0.000612
# saldo_medio_var44_ult1  -0.000856  0.000738  0.032833            0.005055
# saldo_medio_var44_ult3   0.000297  0.000778  0.033597            0.006590
# var38                   -0.005687  0.000071  0.006497            0.000007
# TARGET                   0.003148  0.004475  0.101322           -0.000017
#
#                          imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# ID                                     -0.001436                -0.004131
# var3                                    0.005989                 0.006817
# var15                                   0.094762                 0.101177
# imp_ent_var16_ult1                      0.041221                 0.034879
# imp_op_var39_comer_ult1                 1.000000                 0.886476
# ...                                          ...                      ...
# saldo_medio_var44_hace3                 0.005532                 0.006359
# saldo_medio_var44_ult1                  0.011665                 0.010660
# saldo_medio_var44_ult3                  0.010802                 0.009822
# var38                                   0.012546                 0.013271
# TARGET                                  0.010353                 0.003517
#
#                          imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# ID                                     -0.007277                -0.006302
# var3                                    0.001518                 0.001690
# var15                                   0.042754                 0.048512
# imp_ent_var16_ult1                      0.009896                 0.009377
# imp_op_var39_comer_ult1                 0.342709                 0.295295
# ...                                          ...                      ...
# saldo_medio_var44_hace3                -0.000480                -0.000529
# saldo_medio_var44_ult1                 -0.000254                -0.000510
# saldo_medio_var44_ult3                 -0.000372                -0.000601
# var38                                   0.016628                 0.015584
# TARGET                                  0.003119                -0.000358
#
#                          imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  \
# ID                                     -0.006700                -0.006698
# var3                                    0.000530                 0.000611
# var15                                   0.008805                 0.009678
# imp_ent_var16_ult1                      0.000592                 0.002510
# imp_op_var39_comer_ult1                 0.032280                 0.054809
# ...                                          ...                      ...
# saldo_medio_var44_hace3                -0.000170                -0.000195
# saldo_medio_var44_ult1                 -0.000254                -0.000292
# saldo_medio_var44_ult3                 -0.000268                -0.000308
# var38                                  -0.000315                 0.000682
# TARGET                                  0.019221                 0.019965
#
#                          ...  saldo_medio_var33_hace2  \
# ID                       ...                 0.001986
# var3                     ...                 0.000716
# var15                    ...                 0.029358
# imp_ent_var16_ult1       ...                -0.000864
# imp_op_var39_comer_ult1  ...                 0.016422
# ...                      ...                      ...
# saldo_medio_var44_hace3  ...                -0.000219
# saldo_medio_var44_ult1   ...                 0.000819
# saldo_medio_var44_ult3   ...                 0.000977
# var38                    ...                 0.004448
# TARGET                   ...                -0.003533
#
#                          saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# ID                                      0.003771               -0.001521
# var3                                    0.000491                0.000638
# var15                                   0.017264                0.028504
# imp_ent_var16_ult1                     -0.000632               -0.000548
# imp_op_var39_comer_ult1                 0.011719                0.012570
# ...                                          ...                     ...
# saldo_medio_var44_hace3                -0.000151               -0.000196
# saldo_medio_var44_ult1                 -0.000225                0.002493
# saldo_medio_var44_ult3                 -0.000238                0.002905
# var38                                   0.001605                0.004255
# TARGET                                 -0.002431               -0.003166
#
#                          saldo_medio_var33_ult3  saldo_medio_var44_hace2  \
# ID                                    -0.001216                -0.003772
# var3                                   0.000669                 0.000617
# var15                                  0.029176                 0.029180
# imp_ent_var16_ult1                    -0.000540                 0.002655
# imp_op_var39_comer_ult1                0.013703                 0.009445
# ...                                         ...                      ...
# saldo_medio_var44_hace3               -0.000205                 0.332172
# saldo_medio_var44_ult1                 0.002205                 0.818300
# saldo_medio_var44_ult3                 0.002574                 0.710593
# var38                                  0.004290                 0.002889
# TARGET                                -0.003311                -0.003177
#
#                          saldo_medio_var44_hace3  saldo_medio_var44_ult1  \
# ID                                     -0.003674               -0.000856
# var3                                    0.000508                0.000738
# var15                                   0.018884                0.032833
# imp_ent_var16_ult1                     -0.000612                0.005055
# imp_op_var39_comer_ult1                 0.005532                0.011665
# ...                                          ...                     ...
# saldo_medio_var44_hace3                 1.000000                0.229158
# saldo_medio_var44_ult1                  0.229158                1.000000
# saldo_medio_var44_ult3                  0.213191                0.968167
# var38                                   0.003646                0.003258
# TARGET                                 -0.002553               -0.003104
#
#                          saldo_medio_var44_ult3     var38    TARGET
# ID                                     0.000297 -0.005687  0.003148
# var3                                   0.000778  0.000071  0.004475
# var15                                  0.033597  0.006497  0.101322
# imp_ent_var16_ult1                     0.006590  0.000007 -0.000017
# imp_op_var39_comer_ult1                0.010802  0.012546  0.010353
# ...                                         ...       ...       ...
# saldo_medio_var44_hace3                0.213191  0.003646 -0.002553
# saldo_medio_var44_ult1                 0.968167  0.003258 -0.003104
# saldo_medio_var44_ult3                 1.000000  0.003037 -0.003015
# var38                                  0.003037  1.000000 -0.019510
# TARGET                                -0.003015 -0.019510  1.000000
#
# [371 rows x 371 columns]

# %%
# Import dos módulos
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler

# Carregando os dados
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.values

# Separando o array em componentes de input (X) e output (Y)
x= array[:,0:370]
y= array[:,370]

# Gerando a nova escala (normalizando os dados)
scaler = MinMaxScaler(feature_range = (0, 1))
rescaledX = scaler.fit_transform(x)

print(dados.values)
print(rescaledX[0:5,:])
# Out:
# [[1.00000000e+00 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   3.92051700e+04 0.00000000e+00]
#  [3.00000000e+00 2.00000000e+00 3.40000000e+01 ... 0.00000000e+00
#   4.92780300e+04 0.00000000e+00]
#  [4.00000000e+00 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   6.73337700e+04 0.00000000e+00]
#  ...
#  [1.51835000e+05 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   7.40281500e+04 0.00000000e+00]
#  [1.51836000e+05 2.00000000e+00 2.50000000e+01 ... 0.00000000e+00
#   8.42781600e+04 0.00000000e+00]
#  [1.51838000e+05 2.00000000e+00 4.60000000e+01 ... 0.00000000e+00
#   1.17310979e+05 0.00000000e+00]]
# [[0.00000000e+00 9.99764056e-01 1.80000000e-01 ... 0.00000000e+00
#   0.00000000e+00 1.54525995e-03]
#  [1.31720200e-05 9.99764056e-01 2.90000000e-01 ... 0.00000000e+00
#   0.00000000e+00 2.00250254e-03]
#  [1.97580300e-05 9.99764056e-01 1.80000000e-01 ... 0.00000000e+00
#   0.00000000e+00 2.82211618e-03]
#  [4.61020700e-05 9.99764056e-01 3.20000000e-01 ... 0.00000000e+00
#   0.00000000e+00 2.67114640e-03]
#  [5.92740900e-05 9.99764056e-01 3.40000000e-01 ... 0.00000000e+00
#   0.00000000e+00 5.09075772e-03]]

# %%
# Import dos módulos
from pandas import read_csv
from sklearn.preprocessing import StandardScaler

# Carregando os dados
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.values

# Separando o array em componentes de input (X) e output (Y)
x= array[:,0:370]
y= array[:,370]

# Gerando a nova escala (normalizando os dados)
scaler = StandardScaler().fit(x)
StandardScalerX = scaler.transform(x)

print(dados.values)
print(StandardScalerX[0:5,:])
# Out:
# [[1.00000000e+00 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   3.92051700e+04 0.00000000e+00]
#  [3.00000000e+00 2.00000000e+00 3.40000000e+01 ... 0.00000000e+00
#   4.92780300e+04 0.00000000e+00]
#  [4.00000000e+00 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   6.73337700e+04 0.00000000e+00]
#  ...
#  [1.51835000e+05 2.00000000e+00 2.30000000e+01 ... 0.00000000e+00
#   7.40281500e+04 0.00000000e+00]
#  [1.51836000e+05 2.00000000e+00 2.50000000e+01 ... 0.00000000e+00
#   8.42781600e+04 0.00000000e+00]
#  [1.51838000e+05 2.00000000e+00 4.60000000e+01 ... 0.00000000e+00
#   1.17310979e+05 0.00000000e+00]]
# [[-1.73504275e+00  3.90744048e-02 -7.88248631e-01 ... -1.88169080e-02
#   -1.98468529e-02 -4.27182680e-01]
#  [-1.73499707e+00  3.90744048e-02  6.07525955e-02 ... -1.88169080e-02
#   -1.98468529e-02 -3.72038298e-01]
#  [-1.73497423e+00  3.90744048e-02 -7.88248631e-01 ... -1.88169080e-02
#   -1.98468529e-02 -2.73191237e-01]
#  [-1.73488287e+00  3.90744048e-02  2.92298385e-01 ... -1.88169080e-02
#   -1.98468529e-02 -2.91398497e-01]
#  [-1.73483718e+00  3.90744048e-02  4.46662244e-01 ... -1.88169080e-02
#   -1.98468529e-02  4.11519699e-04]]

# %%
# Importância do Atributo com o Extra Trees Classifier

# Import dos Módulos
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier

arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.
#  2.15613707e-03 2.85990191e-03 2.11401407e-03 2.71451629e-03
#  0.00000000e+00 1.19734300e-05 3.57309096e-09 7.26456552e-05
#  0.00000000e+00 0.00000000e+00 5.05387006e-04 2.10550398e-03
#  2.60608130e-03 9.01289480e-04 2.88452656e-07 4.16512040e-08
#  0.00000000e+00 9.29236206e-08 1.54226984e-09 3.53044634e-08
#  0.00000000e+00 0.00000000e+00 7.20027297e-08 1.91099582e-06
#  1.48395011e-02 1.92848859e-02 1.16069740e-02 2.02406180e-02
#  0.00000000e+00 1.15869353e-02 2.24375750e-02 9.65891207e-03
#  2.25466886e-02 7.17220878e-04 3.74277274e-04 8.87486844e-04
#  8.44906177e-04 3.52707296e-04 2.19028318e-04 3.26498905e-04
#  3.13953329e-04 3.00090078e-04 1.05833484e-04 2.63051790e-04
#  3.28134045e-04 6.14499850e-06 3.49487870e-06 4.32653743e-06
#  8.73434816e-06 0.00000000e+00 0.00000000e+00 1.94037333e-08
#  1.19588392e-08 7.51125794e-06 7.36524618e-08 1.58444599e-05
#  2.87434503e-05 1.11781096e-08 3.21574867e-10 1.73930499e-06
#  3.00126164e-07 1.79260974e-06 6.47245763e-08 8.21801764e-07
#  2.58904441e-06 2.19213822e-06 3.25216320e-07 3.27054292e-05
#  2.11799719e-05 2.02890779e-01]

# %%
# Import dos módulos
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# Carregando os dados
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.values

# Separando o array em componentes de input (X) e output (Y)
x= array[:,0:370]
y= array[:,370]

# Gerando a nova escala (normalizando os dados)
scaler = MinMaxScaler(feature_range = (0, 1))
rescaledX = scaler.fit_transform(x)

#seleção atributos
pca = PCA(n_components=100)
fit = pca.fit(rescaledX)

print("Variância: %s" % fit.explained_variance_ratio_)
print(fit.components_)
# Out:
# Variância: [2.63803898e-01 1.87131319e-01 9.82460769e-02 8.02522292e-02
#  6.56905192e-02 6.29688231e-02 3.60837666e-02 2.85243558e-02
#  2.76578328e-02 1.61083849e-02 1.38946649e-02 1.31064323e-02
#  1.24877793e-02 9.01031113e-03 6.62582197e-03 6.04047630e-03
#  5.84277366e-03 5.41807385e-03 4.85141458e-03 4.36261255e-03
#  4.12182194e-03 3.72438372e-03 3.60315600e-03 3.37591627e-03
#  3.13075754e-03 2.80090736e-03 2.59464554e-03 2.18233097e-03
#  1.85130944e-03 1.65368547e-03 1.38585498e-03 1.35841347e-03
#  1.25243875e-03 1.15645714e-03 1.08704619e-03 9.35344070e-04
#  8.57588460e-04 8.10508813e-04 7.83007931e-04 6.87369514e-04
#  6.31387625e-04 5.59787465e-04 5.45389019e-04 5.26483412e-04
#  5.08677037e-04 4.78358177e-04 4.22819710e-04 4.11938443e-04
#  3.75991585e-04 3.71060548e-04 3.44320710e-04 3.12367314e-04
#  2.63922102e-04 2.54068854e-04 2.41585452e-04 2.32964412e-04
#  2.25549809e-04 2.14349299e-04 2.04523573e-04 1.98497504e-04
#  1.95836638e-04 1.92844380e-04 1.90680640e-04 1.75490436e-04
#  1.73046298e-04 1.70658996e-04 1.52152062e-04 1.48627796e-04
#  1.44042289e-04 1.37463294e-04 1.28475175e-04 1.23397250e-04
#  1.21281089e-04 1.19286474e-04 9.69454700e-05 9.54654411e-05
#  9.27030889e-05 9.21953966e-05 8.82045230e-05 8.26605099e-05
#  8.06014872e-05 7.34814449e-05 7.33575956e-05 6.99005228e-05
#  6.16220818e-05 6.07376245e-05 5.97711451e-05 5.76385233e-05
#  5.53166325e-05 5.46394775e-05 5.33000047e-05 5.29323828e-05
#  5.08096934e-05 5.01089671e-05 4.77711444e-05 4.75191795e-05
#  4.72548589e-05 4.54251748e-05 4.26997303e-05 4.16458727e-05]
# [[ 1.48571727e-05  1.73716173e-03  1.68017905e-02 ...  9.31006268e-05
#    1.09829490e-04 -3.03090900e-04]
#  [-1.57483703e-03 -4.63133832e-04  3.44302668e-02 ...  6.73340573e-05
#    9.34255868e-05  1.90490696e-04]
#  [-2.76599701e-03  6.45621669e-04  8.45061752e-02 ...  6.43900197e-05
#    9.48926465e-05  3.88956314e-04]
#  ...
#  [ 2.09619152e-06 -1.65309081e-04 -1.53350457e-03 ... -1.02594488e-01
#   -1.21697239e-01  8.92847245e-03]
#  [ 3.73369707e-05  6.66827196e-04 -2.20139311e-04 ... -5.84614897e-02
#   -6.66611423e-02 -7.56259482e-03]
#  [ 1.76814146e-04 -6.40543349e-05 -8.88046204e-04 ...  8.60814436e-02
#    1.02393316e-01  5.04583650e-03]]

# %%
# Avaliação usando Cross Validation

# Import dos módulos
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Carregando os dados
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.values

# Separando o array em componentes de input (X) e output (Y)
x= array[:,0:370]
y= array[:,370]

# Definindo o tamanho das amostras
teste_size = 0.4

# Garante que os resultados podem ser reproduzidos
# Isso é importante para comparar a acurácia com outros algoritmos de Machine Learning.
seed = 7

# Criando os conjuntos de dados de treino e de teste
X_treino, X_teste, Y_treino, Y_teste = train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = LogisticRegression()

# Treinamento do modelo
modelo.fit(X_treino, Y_treino)

# Score do modelo nos dados de teste
result = modelo.score(X_teste, Y_teste)
print("Acurácia nos Dados de Teste: %.3f%%" % (result * 100.0))
# Out:
# Acurácia nos Dados de Teste: 96.054%

# %%
# Avaliação usando Cross Validation

# Import dos módulos
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Carregando os dados
arquivo = 'data/train.csv/train.csv'
dados = read_csv(arquivo)
array= dados.values


# Separando o array em componentes de input e output
x= array[:,0:370]
y= array[:,370]


# Definindo os valores para os folds
num_folds = 10
seed = 7

# Separando os dados em folds
kfold = KFold(num_folds, True, random_state = seed)

# Criando o modelo
modelo = LogisticRegression()
resultado = cross_val_score(modelo, x, y, cv = kfold)

# Usamos a média e o desvio padrão
print("Acurácia Final: %.3f%%" % (resultado.mean() * 100.0))
# Out:
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Acurácia Final: 96.030%
# C:\Users\yuki_\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
